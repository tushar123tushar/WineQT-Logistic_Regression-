# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data_set = pd.read_csv('WineQT.csv')

# %%
data_set
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
sns.heatmap(data_set.isnull() , yticklabels=False , cbar=False)
# Out:
# <Axes: >

# %%
x = data_set.drop('quality' , axis=1)
y = data_set['quality']

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1138    6
# 1139    6
# 1140    5
# 1141    6
# 1142    5
# Name: quality, Length: 1143, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 204            12.0              0.45         0.55             2.0      0.073
# 618             7.3              0.35         0.24             2.0      0.067
# 1140            6.2              0.60         0.08             2.0      0.090
# 478            10.8              0.40         0.41             2.2      0.084
# 365            10.5              0.51         0.64             2.4      0.107
# ...             ...               ...          ...             ...        ...
# 1044            6.7              1.04         0.08             2.3      0.067
# 1095            8.0              0.39         0.30             1.9      0.074
# 1130            7.4              0.35         0.33             2.4      0.068
# 860             7.9              0.57         0.31             2.0      0.079
# 1126            7.5              0.52         0.40             2.2      0.060
#
# ...

# %%
y_train
# Out:
# 204     6
# 618     4
# 1140    5
# 478     6
# 365     7
#        ..
# 1044    4
# 1095    5
# 1130    6
# 860     6
# 1126    6
# Name: quality, Length: 765, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

logistic = LogisticRegression()

# %%
parameters  = {'penalty': ['elasticnet', 'l2', 'l1'] , 'C' : [1,2,3,4,5,6,10,5,450,102] , 'max_iter':[100,200,300]}

# %%
class_fire = GridSearchCV(logistic , param_grid=parameters , scoring='accuracy' , cv=5)
class_fire
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [1, 2, 3, 4, 5, 6, 10, 5, 450, 102],
#                          'max_iter': [100, 200, 300],
#                          'penalty': ['elasticnet', 'l2', 'l1']},
#              scoring='accuracy')

# %%
class_fire.fit(X_train , y_train)
# Out:
# c:\Users\A PLUS COM\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\A PLUS COM\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
print(class_fire.best_params_)
# Out:
# {'C': 10, 'max_iter': 300, 'penalty': 'l2'}

# %%
print(class_fire.best_score_)
# Out:
# 0.5111111111111111

# %%
from sklearn.metrics import r2_score , accuracy_score , classification_report
x_pred = class_fire.predict(X_test)

# %%
accuracy_score(x_pred , y_test)
# Out:
# 0.5132275132275133

# %%
classification_report(x_pred , y_test)
# Out:
# c:\Users\A PLUS COM\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\A PLUS COM\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\A PLUS COM\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...
